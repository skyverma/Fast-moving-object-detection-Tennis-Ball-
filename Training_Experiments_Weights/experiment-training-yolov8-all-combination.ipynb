# %%
# Install ultralytics package which includes YOLOv8
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.1/877.1 kB 18.3 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO
import os

# Disable Weights & Biases logging
os.environ['WANDB_MODE'] = 'disabled'

# Load the pretrained YOLOv8 model
model = YOLO('yolov8x.pt')

# Train the model using the custom dataset with more diverse augmentations
from ultralytics import YOLO
import os

# Disable Weights & Biases logging
os.environ['WANDB_MODE'] = 'disabled'

# Load the pretrained YOLOv8 model
model = YOLO('yolov8x.pt')

# Train the model using the custom dataset with other augmentations
model.train(data='/kaggle/input/dataset-for-initial-training/data.yaml',
            epochs=150,             # More epochs for better learning
            imgsz=640,              # Image size
            batch=8,                # Batch size, keeping it low for Kaggle
            patience=10,            # Increase patience to allow better convergence
            lr0=1e-3,               # Learning rate
            lrf=1e-4,               # Final learning rate (using a cosine scheduler)
            optimizer='Adam',       # Adam optimizer for better handling of gradients
            augment=True,           # Enable data augmentations
            hsv_h=0.015,            # Hue augmentation
            hsv_s=0.7,              # Saturation augmentation
            hsv_v=0.4,              # Brightness augmentation
            fliplr=0.5,             # Horizontal flip
            flipud=0.2,             # Vertical flip for more diversity
            mosaic=1.0,             # Use mosaic augmentation
            mixup=0.5,              # Mixup images to improve generalization
            perspective=0.0005,     # Add slight perspective augmentation
            scale=0.5,              # Scale augmentation for zooming in/out
            shear=0.1,              # Shear augmentation to distort slightly
            cache=True)             # Cache images for faster training
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 314MB/s]
# Ultralytics 8.3.20 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Evaluate the model on the test set
results = model.val()
