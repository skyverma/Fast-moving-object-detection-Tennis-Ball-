# %%
# Unzip the dataset
import zipfile
import os

# Install ultralytics package which includes YOLOv8
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.1/877.1 kB 19.9 MB/s eta 0:00:0000:01
# ...

# %%
import os

# Disable Weights & Biases
os.environ['WANDB_MODE'] = 'disabled'

# %%
# Import the YOLO class from ultralytics
from ultralytics import YOLO

# # Load the pretrained YOLOv8 model
# model = YOLO('yolov8x.pt')
# from ultralytics import YOLO

# Load the pretrained YOLOv8 model
model = YOLO('yolov8x.pt')

# Train the model using the custom dataset
model.train(data='/kaggle/input/dataset-for-initial-training/data.yaml',
            epochs=100,           # Number of epochs
            imgsz=640,            # Image size
            batch=8,              # Reduce batch size to avoid GPU memory issues
            patience=5,           # Early stopping if no improvement
            lr0=1e-3,             # Learning rate, lower if unstable
            optimizer='Adam',     # Adam optimizer for better performance on small datasets
            augment=True,         # Enable augmentations
            hsv_h=0.015,          # Color augmentations (hue, saturation, brightness)
            hsv_s=0.7,
            hsv_v=0.4,
            fliplr=0.5,           # Horizontal flip
            mosaic=1.0,           # Use mosaic augmentation
            cache=True)           # Cache images for faster training
# Out:
# Ultralytics 8.3.20 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Evaluate the model on the test set
results = model.val()
# Out:
# Ultralytics 8.3.20 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /kaggle/input/dataset-for-initial-training/valid/labels... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<00:00, 517.81it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/dataset-for-initial-training/valid is not writeable, cache not saved.
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.1GB RAM): 100%|██████████| 100/100 [00:00<00:00, 435.93it/s]
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ...

# %%
# Perform inference on a new image
results = model.predict(source='/kaggle/input/dataset-for-initial-training/test/images', save=True)
# Out:
# image 1/50 /kaggle/input/dataset-for-initial-training/test/images/synframe101_jpg.rf.1f308718bf44dcb6dd10e32ce9fc6cd5.jpg: 384x640 (no detections), 150.9ms
# image 2/50 /kaggle/input/dataset-for-initial-training/test/images/synframe119_jpg.rf.86ddef4b7c7c996344879b9f79c46ddf.jpg: 384x640 1 tennis ball, 111.4ms
# image 3/50 /kaggle/input/dataset-for-initial-training/test/images/synframe122_jpg.rf.9f84517312ec31ca29cfd1b828dfe647.jpg: 384x640 2 tennis balls, 96.0ms
# image 4/50 /kaggle/input/dataset-for-initial-training/test/images/synframe1247_jpg.rf.f1141dda575c60eeb4b7a29a583c1afa.jpg: 384x640 (no detections), 99.3ms
# image 5/50 /kaggle/input/dataset-for-initial-training/test/images/synframe136_jpg.rf.750bbb8f3e5d2922a3b9c2758a1b4ac2.jpg: 384x640 (no detections), 96.3ms
# image 6/50 /kaggle/input/dataset-for-initial-training/test/images/synframe151_jpg.rf.73b75aa9ccab962d663e0b3d17cb0bbf.jpg: 384x640 (no detections), 101.8ms
# ...
